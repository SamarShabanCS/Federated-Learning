# %%
#Importing Libraries

# %%
import torch
from torchvision.datasets import MNIST
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %%
#load Dataset
train_dataset = MNIST('/kaggle/working', train=True, download=True, transform=transforms.ToTensor())
test_dataset = MNIST('/kaggle/working', train=False, download=True, transform=transforms.ToTensor())

train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 188893786.24it/s]
# Extracting /kaggle/working/MNIST/raw/train-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 55977677.37it/s]
# Extracting /kaggle/working/MNIST/raw/train-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 46088736.18it/s]
# Extracting /kaggle/working/MNIST/raw/t10k-images-idx3-ubyte.gz to /kaggle/working/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 17672104.61it/s]
# Extracting /kaggle/working/MNIST/raw/t10k-labels-idx1-ubyte.gz to /kaggle/working/MNIST/raw

# %%
#Define some constants
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

classes = 10
input_dim = 784

num_clients = 8
rounds = 30
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# %%
total_train_size, total_dev_size, total_test_size
# Out:
# (49800, 10200, 10000)

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
            return len(self.dl)

device = get_device()

# %%
#Define FederatedNet class
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 20, 7)
        self.conv2 = torch.nn.Conv2d(20, 40, 7)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(2560, 10)
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}

    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %%
#Define Client Class
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# %%
#setup client


examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %%
#start server


global_net = to_device(FederatedNet(), device)
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))
# Out:
# Start Round 1 ...
# client_0: Loss = 0.5016, Accuracy = 0.8491
# client_1: Loss = 0.5189, Accuracy = 0.8484
# client_2: Loss = 0.5053, Accuracy = 0.8527
# client_3: Loss = 0.4952, Accuracy = 0.8487
# client_4: Loss = 0.5215, Accuracy = 0.8426
# client_5: Loss = 0.51, Accuracy = 0.8437
# client_6: Loss = 0.5101, Accuracy = 0.8475
# client_7: Loss = 0.5089, Accuracy = 0.839
# After round 1, train_loss = 0.4069, dev_loss = 0.4076, dev_acc = 0.8809
#
# Start Round 2 ...
# client_0: Loss = 0.3226, Accuracy = 0.9057
# client_1: Loss = 0.3324, Accuracy = 0.9052
# client_2: Loss = 0.3064, Accuracy = 0.91
# client_3: Loss = 0.3053, Accuracy = 0.9117
# client_4: Loss = 0.3273, Accuracy = 0.9026
# client_5: Loss = 0.3204, Accuracy = 0.9098
# client_6: Loss = 0.323, Accuracy = 0.9108
# client_7: Loss = 0.3244, Accuracy = 0.9028
# After round 2, train_loss = 0.2922, dev_loss = 0.2966, dev_acc = 0.9142
#
# Start Round 3 ...
# client_0: Loss = 0.2347, Accuracy = 0.93
# client_1: Loss = 0.2425, Accuracy = 0.9311
# client_2: Loss = 0.2292, Accuracy = 0.933
# client_3: Loss = 0.2267, Accuracy = 0.9353
# client_4: Loss = 0.2416, Accuracy = 0.9287
# client_5: Loss = 0.2346, Accuracy = 0.9333
# client_6: Loss = 0.246, Accuracy = 0.9311
# client_7: Loss = 0.2367, Accuracy = 0.93
# After round 3, train_loss = 0.2193, dev_loss = 0.2255, dev_acc = 0.934
#
# Start Round 4 ...
# client_0: Loss = 0.1804, Accuracy = 0.9478
# client_1: Loss = 0.1883, Accuracy = 0.9471
# client_2: Loss = 0.1777, Accuracy = 0.9503
# client_3: Loss = 0.1735, Accuracy = 0.9502
# client_4: Loss = 0.1861, Accuracy = 0.9478
# client_5: Loss = 0.1821, Accuracy = 0.9479
# client_6: Loss = 0.1937, Accuracy = 0.9457
# client_7: Loss = 0.1842, Accuracy = 0.9466
# After round 4, train_loss = 0.1732, dev_loss = 0.1785, dev_acc = 0.9471
#
# Start Round 5 ...
# client_0: Loss = 0.1491, Accuracy = 0.9579
# client_1: Loss = 0.1565, Accuracy = 0.9548
# client_2: Loss = 0.1474, Accuracy = 0.9573
# client_3: Loss = 0.1368, Accuracy = 0.9603
# client_4: Loss = 0.154, Accuracy = 0.9538
# client_5: Loss = 0.1477, Accuracy = 0.958
# client_6: Loss = 0.1574, Accuracy = 0.9554
# client_7: Loss = 0.1489, Accuracy = 0.9565
# After round 5, train_loss = 0.1444, dev_loss = 0.1496, dev_acc = 0.9574
#
# Start Round 6 ...
# client_0: Loss = 0.125, Accuracy = 0.9649
# client_1: Loss = 0.1322, Accuracy = 0.9631
# client_2: Loss = 0.1267, Accuracy = 0.9631
# client_3: Loss = 0.1168, Accuracy = 0.967
# client_4: Loss = 0.1341, Accuracy = 0.961
# client_5: Loss = 0.1267, Accuracy = 0.9671
# client_6: Loss = 0.1364, Accuracy = 0.9629
# client_7: Loss = 0.1278, Accuracy = 0.9631
# After round 6, train_loss = 0.1239, dev_loss = 0.1278, dev_acc = 0.9632
#
# Start Round 7 ...
# client_0: Loss = 0.1117, Accuracy = 0.967
# client_1: Loss = 0.1197, Accuracy = 0.9636
# client_2: Loss = 0.1124, Accuracy = 0.9679
# client_3: Loss = 0.101, Accuracy = 0.9714
# client_4: Loss = 0.117, Accuracy = 0.9659
# client_5: Loss = 0.1108, Accuracy = 0.9683
# client_6: Loss = 0.1214, Accuracy = 0.9666
# client_7: Loss = 0.1127, Accuracy = 0.9682
# After round 7, train_loss = 0.1094, dev_loss = 0.1133, dev_acc = 0.967
#
# Start Round 8 ...
# client_0: Loss = 0.095, Accuracy = 0.973
# client_1: Loss = 0.1045, Accuracy = 0.9691
# client_2: Loss = 0.1007, Accuracy = 0.9713
# client_3: Loss = 0.0911, Accuracy = 0.9716
# client_4: Loss = 0.1058, Accuracy = 0.9697
# client_5: Loss = 0.0997, Accuracy = 0.9736
# client_6: Loss = 0.1081, Accuracy = 0.9719
# client_7: Loss = 0.1048, Accuracy = 0.9708
# After round 8, train_loss = 0.1001, dev_loss = 0.1039, dev_acc = 0.9697
#
# Start Round 9 ...
# client_0: Loss = 0.0875, Accuracy = 0.9754
# client_1: Loss = 0.0947, Accuracy = 0.9721
# client_2: Loss = 0.0899, Accuracy = 0.9733
# client_3: Loss = 0.0809, Accuracy = 0.9756
# client_4: Loss = 0.0966, Accuracy = 0.9698
# client_5: Loss = 0.091, Accuracy = 0.9748
# client_6: Loss = 0.0994, Accuracy = 0.9749
# client_7: Loss = 0.0961, Accuracy = 0.9728
# After round 9, train_loss = 0.0909, dev_loss = 0.0953, dev_acc = 0.9724
#
# Start Round 10 ...
# client_0: Loss = 0.0796, Accuracy = 0.9764
# client_1: Loss = 0.0872, Accuracy = 0.9734
# client_2: Loss = 0.0833, Accuracy = 0.9774
# client_3: Loss = 0.0748, Accuracy = 0.9773
# client_4: Loss = 0.0897, Accuracy = 0.9736
# client_5: Loss = 0.084, Accuracy = 0.9764
# client_6: Loss = 0.0909, Accuracy = 0.9764
# client_7: Loss = 0.0861, Accuracy = 0.975
# After round 10, train_loss = 0.0844, dev_loss = 0.0888, dev_acc = 0.9737
#
# Start Round 11 ...
# client_0: Loss = 0.073, Accuracy = 0.9776
# client_1: Loss = 0.081, Accuracy = 0.9763
# client_2: Loss = 0.0778, Accuracy = 0.9784
# client_3: Loss = 0.0683, Accuracy = 0.9796
# client_4: Loss = 0.0825, Accuracy = 0.9746
# client_5: Loss = 0.0786, Accuracy = 0.9792
# client_6: Loss = 0.0853, Accuracy = 0.9765
# client_7: Loss = 0.0814, Accuracy = 0.9758
# After round 11, train_loss = 0.0792, dev_loss = 0.084, dev_acc = 0.9741
#
# Start Round 12 ...
# client_0: Loss = 0.0693, Accuracy = 0.9789
# client_1: Loss = 0.077, Accuracy = 0.9757
# client_2: Loss = 0.0735, Accuracy = 0.9781
# client_3: Loss = 0.0632, Accuracy = 0.98
# client_4: Loss = 0.08, Accuracy = 0.9771
# client_5: Loss = 0.0753, Accuracy = 0.9785
# client_6: Loss = 0.08, Accuracy = 0.9788
# client_7: Loss = 0.0764, Accuracy = 0.9778
# After round 12, train_loss = 0.0748, dev_loss = 0.0803, dev_acc = 0.9761
#
# Start Round 13 ...
# client_0: Loss = 0.065, Accuracy = 0.979
# client_1: Loss = 0.07, Accuracy = 0.979
# client_2: Loss = 0.0704, Accuracy = 0.9811
# client_3: Loss = 0.0593, Accuracy = 0.9816
# client_4: Loss = 0.075, Accuracy = 0.9799
# client_5: Loss = 0.0698, Accuracy = 0.98
# client_6: Loss = 0.0783, Accuracy = 0.9785
# client_7: Loss = 0.0725, Accuracy = 0.9792
# After round 13, train_loss = 0.071, dev_loss = 0.0771, dev_acc = 0.9765
#
# Start Round 14 ...
# client_0: Loss = 0.0605, Accuracy = 0.9813
# client_1: Loss = 0.0661, Accuracy = 0.9793
# client_2: Loss = 0.0663, Accuracy = 0.9809
# client_3: Loss = 0.056, Accuracy = 0.9826
# client_4: Loss = 0.0704, Accuracy = 0.979
# client_5: Loss = 0.0665, Accuracy = 0.9803
# client_6: Loss = 0.0725, Accuracy = 0.981
# client_7: Loss = 0.0691, Accuracy = 0.9792
# After round 14, train_loss = 0.0679, dev_loss = 0.0743, dev_acc = 0.9769
#
# Start Round 15 ...
# client_0: Loss = 0.0573, Accuracy = 0.9824
# client_1: Loss = 0.0628, Accuracy = 0.9796
# client_2: Loss = 0.0621, Accuracy = 0.9816
# client_3: Loss = 0.0535, Accuracy = 0.9833
# client_4: Loss = 0.067, Accuracy = 0.9801
# client_5: Loss = 0.0632, Accuracy = 0.9825
# client_6: Loss = 0.0667, Accuracy = 0.9831
# client_7: Loss = 0.0647, Accuracy = 0.9805
# After round 15, train_loss = 0.0653, dev_loss = 0.0722, dev_acc = 0.9782
#
# Start Round 16 ...
# client_0: Loss = 0.0547, Accuracy = 0.9843
# client_1: Loss = 0.0616, Accuracy = 0.9811
# client_2: Loss = 0.0601, Accuracy = 0.9828
# client_3: Loss = 0.052, Accuracy = 0.9833
# client_4: Loss = 0.0644, Accuracy = 0.9812
# client_5: Loss = 0.0595, Accuracy = 0.9828
# client_6: Loss = 0.0676, Accuracy = 0.9824
# client_7: Loss = 0.0632, Accuracy = 0.9805
# After round 16, train_loss = 0.0621, dev_loss = 0.0693, dev_acc = 0.9783
#
# Start Round 17 ...
# client_0: Loss = 0.0518, Accuracy = 0.9857
# client_1: Loss = 0.0567, Accuracy = 0.9837
# client_2: Loss = 0.0591, Accuracy = 0.9823
# client_3: Loss = 0.0485, Accuracy = 0.9848
# client_4: Loss = 0.062, Accuracy = 0.9822
# client_5: Loss = 0.0576, Accuracy = 0.9822
# client_6: Loss = 0.0636, Accuracy = 0.9827
# client_7: Loss = 0.0616, Accuracy = 0.9831
# After round 17, train_loss = 0.0599, dev_loss = 0.0675, dev_acc = 0.9789
#
# Start Round 18 ...
# client_0: Loss = 0.0502, Accuracy = 0.9842
# client_1: Loss = 0.0552, Accuracy = 0.9845
# client_2: Loss = 0.0556, Accuracy = 0.9824
# client_3: Loss = 0.045, Accuracy = 0.986
# client_4: Loss = 0.06, Accuracy = 0.9824
# client_5: Loss = 0.0545, Accuracy = 0.9853
# client_6: Loss = 0.0594, Accuracy = 0.9856
# client_7: Loss = 0.058, Accuracy = 0.9831
# After round 18, train_loss = 0.0575, dev_loss = 0.0657, dev_acc = 0.9789
#
# Start Round 19 ...
# client_0: Loss = 0.0493, Accuracy = 0.9851
# client_1: Loss = 0.0521, Accuracy = 0.9842
# client_2: Loss = 0.0538, Accuracy = 0.9838
# client_3: Loss = 0.0439, Accuracy = 0.986
# client_4: Loss = 0.0577, Accuracy = 0.984
# client_5: Loss = 0.0517, Accuracy = 0.9846
# client_6: Loss = 0.0583, Accuracy = 0.9853
# client_7: Loss = 0.0563, Accuracy = 0.9841
# After round 19, train_loss = 0.056, dev_loss = 0.0643, dev_acc = 0.9789
#
# Start Round 20 ...
# client_0: Loss = 0.0472, Accuracy = 0.9853
# client_1: Loss = 0.0516, Accuracy = 0.9834
# client_2: Loss = 0.0512, Accuracy = 0.9841
# client_3: Loss = 0.0414, Accuracy = 0.9878
# client_4: Loss = 0.0575, Accuracy = 0.9828
# client_5: Loss = 0.0509, Accuracy = 0.9855
# client_6: Loss = 0.056, Accuracy = 0.9859
# client_7: Loss = 0.0547, Accuracy = 0.9845
# After round 20, train_loss = 0.0539, dev_loss = 0.0628, dev_acc = 0.98
#
# Start Round 21 ...
# client_0: Loss = 0.0447, Accuracy = 0.9863
# client_1: Loss = 0.0486, Accuracy = 0.9848
# client_2: Loss = 0.0493, Accuracy = 0.9851
# client_3: Loss = 0.0408, Accuracy = 0.9875
# client_4: Loss = 0.0534, Accuracy = 0.9845
# client_5: Loss = 0.0479, Accuracy = 0.986
# client_6: Loss = 0.0537, Accuracy = 0.9848
# client_7: Loss = 0.053, Accuracy = 0.9851
# After round 21, train_loss = 0.0522, dev_loss = 0.0614, dev_acc = 0.9803
#
# Start Round 22 ...
# client_0: Loss = 0.0436, Accuracy = 0.9875
# client_1: Loss = 0.0464, Accuracy = 0.9854
# client_2: Loss = 0.0492, Accuracy = 0.9844
# client_3: Loss = 0.0399, Accuracy = 0.9874
# client_4: Loss = 0.0532, Accuracy = 0.985
# client_5: Loss = 0.0487, Accuracy = 0.9858
# client_6: Loss = 0.0515, Accuracy = 0.9879
# client_7: Loss = 0.0522, Accuracy = 0.9843
# After round 22, train_loss = 0.0509, dev_loss = 0.0603, dev_acc = 0.9812
#
# Start Round 23 ...
# client_0: Loss = 0.0421, Accuracy = 0.9883
# client_1: Loss = 0.0445, Accuracy = 0.9858
# client_2: Loss = 0.0464, Accuracy = 0.9857
# client_3: Loss = 0.0385, Accuracy = 0.9877
# client_4: Loss = 0.0501, Accuracy = 0.9854
# client_5: Loss = 0.0464, Accuracy = 0.9856
# client_6: Loss = 0.0511, Accuracy = 0.9869
# client_7: Loss = 0.0487, Accuracy = 0.9855
# After round 23, train_loss = 0.0498, dev_loss = 0.0593, dev_acc = 0.9809
#
# Start Round 24 ...
# client_0: Loss = 0.041, Accuracy = 0.9882
# client_1: Loss = 0.0439, Accuracy = 0.9857
# client_2: Loss = 0.045, Accuracy = 0.9862
# client_3: Loss = 0.0375, Accuracy = 0.9874
# client_4: Loss = 0.0499, Accuracy = 0.9839
# client_5: Loss = 0.0447, Accuracy = 0.9869
# client_6: Loss = 0.0503, Accuracy = 0.9872
# client_7: Loss = 0.0485, Accuracy = 0.986
# After round 24, train_loss = 0.0485, dev_loss = 0.0578, dev_acc = 0.9816
#
# Start Round 25 ...
# client_0: Loss = 0.0386, Accuracy = 0.9889
# client_1: Loss = 0.0428, Accuracy = 0.9885
# client_2: Loss = 0.0433, Accuracy = 0.9873
# client_3: Loss = 0.0363, Accuracy = 0.989
# client_4: Loss = 0.0468, Accuracy = 0.9866
# client_5: Loss = 0.0429, Accuracy = 0.988
# client_6: Loss = 0.048, Accuracy = 0.9867
# client_7: Loss = 0.0458, Accuracy = 0.9868
# After round 25, train_loss = 0.0472, dev_loss = 0.0574, dev_acc = 0.9818
#
# Start Round 26 ...
# client_0: Loss = 0.038, Accuracy = 0.9891
# client_1: Loss = 0.0407, Accuracy = 0.9882
# client_2: Loss = 0.0422, Accuracy = 0.9869
# client_3: Loss = 0.0354, Accuracy = 0.9885
# client_4: Loss = 0.048, Accuracy = 0.9851
# client_5: Loss = 0.0412, Accuracy = 0.9874
# client_6: Loss = 0.0485, Accuracy = 0.9866
# client_7: Loss = 0.0446, Accuracy = 0.9866
# After round 26, train_loss = 0.046, dev_loss = 0.0573, dev_acc = 0.9814
#
# Start Round 27 ...
# client_0: Loss = 0.0371, Accuracy = 0.989
# client_1: Loss = 0.0392, Accuracy = 0.9872
# client_2: Loss = 0.0407, Accuracy = 0.9878
# client_3: Loss = 0.0325, Accuracy = 0.9894
# client_4: Loss = 0.0452, Accuracy = 0.9872
# client_5: Loss = 0.0407, Accuracy = 0.9878
# client_6: Loss = 0.0462, Accuracy = 0.9892
# client_7: Loss = 0.045, Accuracy = 0.9876
# After round 27, train_loss = 0.045, dev_loss = 0.0558, dev_acc = 0.9819
#
# Start Round 28 ...
# client_0: Loss = 0.0358, Accuracy = 0.9898
# client_1: Loss = 0.0388, Accuracy = 0.9877
# client_2: Loss = 0.0385, Accuracy = 0.9896
# client_3: Loss = 0.033, Accuracy = 0.9893
# client_4: Loss = 0.0455, Accuracy = 0.9856
# client_5: Loss = 0.0403, Accuracy = 0.988
# client_6: Loss = 0.0447, Accuracy = 0.9886
# client_7: Loss = 0.0431, Accuracy = 0.9879
# After round 28, train_loss = 0.044, dev_loss = 0.0547, dev_acc = 0.9821
#
# Start Round 29 ...
# client_0: Loss = 0.0343, Accuracy = 0.9895
# client_1: Loss = 0.0363, Accuracy = 0.9895
# client_2: Loss = 0.0394, Accuracy = 0.9885
# client_3: Loss = 0.0316, Accuracy = 0.9907
# client_4: Loss = 0.0426, Accuracy = 0.9864
# client_5: Loss = 0.0388, Accuracy = 0.9879
# client_6: Loss = 0.0431, Accuracy = 0.9897
# client_7: Loss = 0.0424, Accuracy = 0.9876
# After round 29, train_loss = 0.0431, dev_loss = 0.0545, dev_acc = 0.9824
#
# Start Round 30 ...
# client_0: Loss = 0.0334, Accuracy = 0.9913
# client_1: Loss = 0.0349, Accuracy = 0.9893
# client_2: Loss = 0.0376, Accuracy = 0.9889
# client_3: Loss = 0.0309, Accuracy = 0.9908
# client_4: Loss = 0.0414, Accuracy = 0.9872
# client_5: Loss = 0.0365, Accuracy = 0.9899
# client_6: Loss = 0.0427, Accuracy = 0.9897
# client_7: Loss = 0.041, Accuracy = 0.9876
# After round 30, train_loss = 0.0422, dev_loss = 0.0532, dev_acc = 0.9833

# %%
plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
