# %%
import syft as sy

# %% [markdown]
# # Part 1: Join the Duet Server the Data Owner connected to

# %%
duet = sy.join_duet(loopback=True)
# Out:
# 🎤  🎸  ♪♪♪ Joining Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ > Use at your own risk.
#
#
#     > ❤️ Love Duet? Please consider supporting our community!
#     > https://github.com/sponsors/OpenMined
#
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-218-7-180.us-east-2.compute.amazonaws.com:5000
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network...
# ♫♫♫ > DONE!
#
# ♫♫♫ > CONNECTED!

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 0 : Now STOP and run the Data Owner notebook until Checkpoint 1.

# %% [markdown]
# # Part 2: Search for Available Data

# %%
# The data scientist can check the list of searchable data in Data Owner's duet store
duet.store.pandas
# Out:
#                                         ID                  Tags  \
# 0  <UID: b46ec3ee3c934288b0f5f1f04b7383c7>  [HEIGHTS of GROUP A]
# 1  <UID: 6858b2bfb7024b608d228ecc9779ade5>  [WEIGHTS of GROUP A]
#
#                                          Description             object_type
# 0  This is a list of heights (cm) of GROUP A - 6 ...  <class 'torch.Tensor'>
# 1  This is a list of body weights (kg) of GROUP A...  <class 'torch.Tensor'>

# %%
# Data Scientist finds that there are Heights and Weights of a group of people. There are some analysis he/she can do with them together.

heights_ptr = duet.store[0]
weights_ptr = duet.store[1]

# heights_ptr is a reference to the height dataset remotely available on data owner's server
print(heights_ptr)

# weights_ptr is a reference to the weight dataset remotely available on data owner's server
print(weights_ptr)
# Out:
# <syft.proxy.torch.TensorPointer object at 0x7fefb92c81c0>
# <syft.proxy.torch.TensorPointer object at 0x7fefb904d130>

# %% [markdown]
# ## Calculate BMI (Body Mass Index) and weight status
#
# Using the heights and weights pointers of the people of Group A, calculate their BMI and get a pointer to their individual BMI. From the BMI pointers, you can check if a person is normal-weight, overweight or obese, without knowing their actual heights and weights and even BMI values.
#
#     BMI from 19 to 24 - Normal
#     BMI from 25 to 29 - Overweight
#     BMI from 30 to 39 - Obese
#
#     BMI = [weight (kg) / (height (cm)^2)] x 10,000
#     Hint: run duet.torch and find the required operators

# %% [markdown]
# One amazing thing about pointers is that from a pointer to a list of items, we can get the pointers to each item in the list. As example, here we have weights_ptr pointing to the weight-list, but from that we can also get the pointer to each weight and perform computation on each of them without even the knowing the value! Below code will show you how to access the pointers to each weight and height from the list pointer.

# %%
for i in range(6):
    print("Pointer to Weight of person", i + 1, weights_ptr[i].float())
    print("Pointer to Height of person", i + 1, heights_ptr[i].float())
# Out:
# Pointer to Weight of person 1 <syft.proxy.torch.TensorPointer object at 0x7ff0642abf70>
# Pointer to Height of person 1 <syft.proxy.torch.TensorPointer object at 0x7ff06429e4f0>
# Pointer to Weight of person 2 <syft.proxy.torch.TensorPointer object at 0x7fefb91c5880>
# Pointer to Height of person 2 <syft.proxy.torch.TensorPointer object at 0x7fefb92c8220>
# Pointer to Weight of person 3 <syft.proxy.torch.TensorPointer object at 0x7ff06429e4f0>
# Pointer to Height of person 3 <syft.proxy.torch.TensorPointer object at 0x7fefb92c8070>
# Pointer to Weight of person 4 <syft.proxy.torch.TensorPointer object at 0x7ff0642abf70>
# Pointer to Height of person 4 <syft.proxy.torch.TensorPointer object at 0x7fefb91c5eb0>
# Pointer to Weight of person 5 <syft.proxy.torch.TensorPointer object at 0x7ff0642abf70>
# Pointer to Height of person 5 <syft.proxy.torch.TensorPointer object at 0x7fefb92c80a0>
# Pointer to Weight of person 6 <syft.proxy.torch.TensorPointer object at 0x7fefb92c8220>
# Pointer to Height of person 6 <syft.proxy.torch.TensorPointer object at 0x7fefb92c88e0>

# %%
duet.torch
# Out:
# Module:
# 	.Tensor -> <syft.ast.klass.Class object at 0x7f96811cd940>
# 	.BFloat16Tensor -> <syft.ast.klass.Class object at 0x7f96811cd9a0>
# 	.BoolTensor -> <syft.ast.klass.Class object at 0x7f96811cda00>
# 	.ByteTensor -> <syft.ast.klass.Class object at 0x7f96811cda60>
# 	.CharTensor -> <syft.ast.klass.Class object at 0x7f96811cdac0>
# 	.DoubleTensor -> <syft.ast.klass.Class object at 0x7f96811cdb20>
# 	.FloatTensor -> <syft.ast.klass.Class object at 0x7f96811cdb80>
# 	.HalfTensor -> <syft.ast.klass.Class object at 0x7f96811cdbe0>
# 	.IntTensor -> <syft.ast.klass.Class object at 0x7f96811cdc40>
# 	.LongTensor -> <syft.ast.klass.Class object at 0x7f96811cdca0>
# 	.ShortTensor -> <syft.ast.klass.Class object at 0x7f96811cdd00>
# 	.nn -> Module:
# 		.Parameter -> <syft.ast.klass.Class object at 0x7f96811cde20>
# 		.Module -> <syft.ast.klass.Class object at 0x7f968091d460>
# 		.Conv2d -> <syft.ast.klass.Class object at 0x7f968091d940>
# 		.Dropout2d -> <syft.ast.klass.Class object at 0x7f968091dd60>
# 		.Linear -> <syft.ast.klass.Class object at 0x7f9680921100>
# 		.functional -> Module:
# 			.relu -> <syft.ast.callable.Callable object at 0x7f9680921a00>
# 			.gelu -> <syft.ast.callable.Callable object at 0x7f9680921a60>
# 			.max_pool2d -> <syft.ast.callable.Callable object at 0x7f9680921ac0>
# 			.log_softmax -> <syft.ast.callable.Callable object at 0x7f9680921b20>
# 			.cosine_embedding_loss -> <syft.ast.callable.Callable object at 0x7f968092b8e0>
# 			.ctc_loss -> <syft.ast.callable.Callable object at 0x7f968092b940>
# 			.hinge_embedding_loss -> <syft.ast.callable.Callable object at 0x7f968092ba00>
# 			.l1_loss -> <syft.ast.callable.Callable object at 0x7f968092ba60>
# 			.margin_ranking_loss -> <syft.ast.callable.Callable object at 0x7f968092bb20>
# 			.mse_loss -> <syft.ast.callable.Callable object at 0x7f968092bb80>
# 			.multi_margin_loss -> <syft.ast.callable.Callable object at 0x7f968092bc40>
# 			.multilabel_margin_loss -> <syft.ast.callable.Callable object at 0x7f968092bd00>
# 			.multilabel_soft_margin_loss -> <syft.ast.callable.Callable object at 0x7f968092bdc0>
# 			.nll_loss -> <syft.ast.callable.Callable object at 0x7f968092be20>
# 			.cross_entropy -> <syft.ast.callable.Callable object at 0x7f968092bee0>
# 			.poisson_nll_loss -> <syft.ast.callable.Callable object at 0x7f968092bfa0>
# 			.smooth_l1_loss -> <syft.ast.callable.Callable object at 0x7f968092d0a0>
# 			.soft_margin_loss -> <syft.ast.callable.Callable object at 0x7f968092d160>
# 			.triplet_margin_loss -> <syft.ast.callable.Callable object at 0x7f968092d220>
#
# 		.Sequential -> <syft.ast.klass.Class object at 0x7f968092b520>
# 		.AdaptiveLogSoftmaxWithLoss -> <syft.ast.klass.Class object at 0x7f968092d2e0>
# 		.BCELoss -> <syft.ast.klass.Class object at 0x7f968092d460>
# 		.BCEWithLogitsLoss -> <syft.ast.klass.Class object at 0x7f968092d520>
# 		.CTCLoss -> <syft.ast.klass.Class object at 0x7f968092d640>
# 		.CrossEntropyLoss -> <syft.ast.klass.Class object at 0x7f968092d700>
# 		.CosineEmbeddingLoss -> <syft.ast.klass.Class object at 0x7f968092d820>
# 		.HingeEmbeddingLoss -> <syft.ast.klass.Class object at 0x7f968092d940>
# 		.KLDivLoss -> <syft.ast.klass.Class object at 0x7f968092da60>
# 		.L1Loss -> <syft.ast.klass.Class object at 0x7f968092db20>
# 		.MSELoss -> <syft.ast.klass.Class object at 0x7f968092dbe0>
# 		.MarginRankingLoss -> <syft.ast.klass.Class object at 0x7f968092dca0>
# 		.MultiLabelMarginLoss -> <syft.ast.klass.Class object at 0x7f968092ddc0>
# 		.MultiLabelSoftMarginLoss -> <syft.ast.klass.Class object at 0x7f968092df40>
# 		.MultiMarginLoss -> <syft.ast.klass.Class object at 0x7f96809320a0>
# 		.NLLLoss -> <syft.ast.klass.Class object at 0x7f96809321c0>
# 		.NLLLoss2d -> <syft.ast.klass.Class object at 0x7f9680932280>
# 		.PoissonNLLLoss -> <syft.ast.klass.Class object at 0x7f9680932340>
# 		.SmoothL1Loss -> <syft.ast.klass.Class object at 0x7f9680932460>
# 		.SoftMarginLoss -> <syft.ast.klass.Class object at 0x7f9680932520>
# 		.TripletMarginLoss -> <syft.ast.klass.Class object at 0x7f9680932640>
# 		.AdaptiveAvgPool1d -> <syft.ast.klass.Class object at 0x7f9680932760>
# 		.AdaptiveAvgPool2d -> <syft.ast.klass.Class object at 0x7f9680932dc0>
# 		.AdaptiveAvgPool3d -> <syft.ast.klass.Class object at 0x7f9680937460>
# 		.AdaptiveMaxPool1d -> <syft.ast.klass.Class object at 0x7f9680937ac0>
# 		.AdaptiveMaxPool2d -> <syft.ast.klass.Class object at 0x7f9680939160>
# 		.AdaptiveMaxPool3d -> <syft.ast.klass.Class object at 0x7f96809397c0>
# 		.AlphaDropout -> <syft.ast.klass.Class object at 0x7f9680939e20>
# 		.AvgPool1d -> <syft.ast.klass.Class object at 0x7f968093c400>
# 		.AvgPool2d -> <syft.ast.klass.Class object at 0x7f968093c880>
# 		.AvgPool3d -> <syft.ast.klass.Class object at 0x7f968093cd00>
# 		.BatchNorm1d -> <syft.ast.klass.Class object at 0x7f96808c01c0>
# 		.BatchNorm2d -> <syft.ast.klass.Class object at 0x7f96808c0640>
# 		.BatchNorm3d -> <syft.ast.klass.Class object at 0x7f96808c0ac0>
# 		.Bilinear -> <syft.ast.klass.Class object at 0x7f96808c0f40>
# 		.CELU -> <syft.ast.klass.Class object at 0x7f96808c5400>
# 		.ConstantPad1d -> <syft.ast.klass.Class object at 0x7f96808c5820>
# 		.ConstantPad2d -> <syft.ast.klass.Class object at 0x7f96808c5dc0>
# 		.ConstantPad3d -> <syft.ast.klass.Class object at 0x7f96808c73a0>
# 		.Container -> <syft.ast.klass.Class object at 0x7f96808c7940>
# 		.Conv1d -> <syft.ast.klass.Class object at 0x7f96808c7dc0>
# 		.Conv3d -> <syft.ast.klass.Class object at 0x7f96808cc220>
# 		.ConvTranspose1d -> <syft.ast.klass.Class object at 0x7f96808cc640>
# 		.ConvTranspose2d -> <syft.ast.klass.Class object at 0x7f96808ccc40>
# 		.ConvTranspose3d -> <syft.ast.klass.Class object at 0x7f96808d0280>
# 		.CosineSimilarity -> <syft.ast.klass.Class object at 0x7f96808d0880>
# 		.CrossMapLRN2d -> <syft.ast.klass.Class object at 0x7f96808d0e80>
# 		.DataParallel -> <syft.ast.klass.Class object at 0x7f96808d3460>
# 		.Dropout -> <syft.ast.klass.Class object at 0x7f96808d3a00>
# 		.Dropout3d -> <syft.ast.klass.Class object at 0x7f96808d3fa0>
# 		.ELU -> <syft.ast.klass.Class object at 0x7f96808d6460>
# 		.Embedding -> <syft.ast.klass.Class object at 0x7f96808d6820>
# 		.EmbeddingBag -> <syft.ast.klass.Class object at 0x7f96808d6ca0>
# 		.FeatureAlphaDropout -> <syft.ast.klass.Class object at 0x7f96808db280>
# 		.Flatten -> <syft.ast.klass.Class object at 0x7f96808db9a0>
# 		.Fold -> <syft.ast.klass.Class object at 0x7f96808dbe20>
# 		.FractionalMaxPool2d -> <syft.ast.klass.Class object at 0x7f96808de280>
# 		.FractionalMaxPool3d -> <syft.ast.klass.Class object at 0x7f96808de9a0>
# 		.GELU -> <syft.ast.klass.Class object at 0x7f96808e1100>
# 		.GLU -> <syft.ast.klass.Class object at 0x7f96808e1520>
# 		.GRU -> <syft.ast.klass.Class object at 0x7f96808e18e0>
# 		.GRUCell -> <syft.ast.klass.Class object at 0x7f96808e1ca0>
# 		.GroupNorm -> <syft.ast.klass.Class object at 0x7f96808e6160>
# 		.Hardshrink -> <syft.ast.klass.Class object at 0x7f96808e65e0>
# 		.Hardsigmoid -> <syft.ast.klass.Class object at 0x7f96808e6a60>
# 		.Hardswish -> <syft.ast.klass.Class object at 0x7f96808e6e20>
# 		.Hardtanh -> <syft.ast.klass.Class object at 0x7f96808ea220>
# 		.Identity -> <syft.ast.klass.Class object at 0x7f96808ea6a0>
# 		.InstanceNorm1d -> <syft.ast.klass.Class object at 0x7f96808eab20>
# 		.InstanceNorm2d -> <syft.ast.klass.Class object at 0x7f96808f0160>
# 		.InstanceNorm3d -> <syft.ast.klass.Class object at 0x7f96808f0760>
# 		.LPPool1d -> <syft.ast.klass.Class object at 0x7f96808f0d60>
# 		.LPPool2d -> <syft.ast.klass.Class object at 0x7f96808f2220>
# 		.LSTM -> <syft.ast.klass.Class object at 0x7f96808f26a0>
# 		.LSTMCell -> <syft.ast.klass.Class object at 0x7f96808f2ac0>
# 		.LayerNorm -> <syft.ast.klass.Class object at 0x7f96808f2f40>
# 		.LeakyReLU -> <syft.ast.klass.Class object at 0x7f96808f6400>
# 		.LocalResponseNorm -> <syft.ast.klass.Class object at 0x7f96808f6880>
# 		.LogSigmoid -> <syft.ast.klass.Class object at 0x7f96808f6ee0>
# 		.LogSoftmax -> <syft.ast.klass.Class object at 0x7f96808f93a0>
# 		.MaxPool1d -> <syft.ast.klass.Class object at 0x7f96808f9820>
# 		.MaxPool2d -> <syft.ast.klass.Class object at 0x7f96808f9ca0>
# 		.MaxPool3d -> <syft.ast.klass.Class object at 0x7f96808fe160>
# 		.MaxUnpool1d -> <syft.ast.klass.Class object at 0x7f96808fe5e0>
# 		.MaxUnpool2d -> <syft.ast.klass.Class object at 0x7f96808fea60>
# 		.MaxUnpool3d -> <syft.ast.klass.Class object at 0x7f96808feee0>
# 		.ModuleDict -> <syft.ast.klass.Class object at 0x7f96808823a0>
# 		.ModuleList -> <syft.ast.klass.Class object at 0x7f9680882820>
# 		.MultiheadAttention -> <syft.ast.klass.Class object at 0x7f9680882d60>
# 		.PReLU -> <syft.ast.klass.Class object at 0x7f9680886460>
# 		.PairwiseDistance -> <syft.ast.klass.Class object at 0x7f9680886880>
# 		.PixelShuffle -> <syft.ast.klass.Class object at 0x7f9680886e80>
# 		.RNN -> <syft.ast.klass.Class object at 0x7f9680889460>
# 		.RNNBase -> <syft.ast.klass.Class object at 0x7f9680889820>
# 		.RNNCell -> <syft.ast.klass.Class object at 0x7f9680889ca0>
# 		.RNNCellBase -> <syft.ast.klass.Class object at 0x7f968088d160>
# 		.RReLU -> <syft.ast.klass.Class object at 0x7f968088d5e0>
# 		.ReLU -> <syft.ast.klass.Class object at 0x7f968088da00>
# 		.ReLU6 -> <syft.ast.klass.Class object at 0x7f968088de20>
# 		.ReflectionPad1d -> <syft.ast.klass.Class object at 0x7f9680892280>
# 		.ReflectionPad2d -> <syft.ast.klass.Class object at 0x7f9680892880>
# 		.ReplicationPad1d -> <syft.ast.klass.Class object at 0x7f9680892e80>
# 		.ReplicationPad2d -> <syft.ast.klass.Class object at 0x7f96808944c0>
# 		.ReplicationPad3d -> <syft.ast.klass.Class object at 0x7f9680894ac0>
# 		.SELU -> <syft.ast.klass.Class object at 0x7f9680897100>
# 		.Sigmoid -> <syft.ast.klass.Class object at 0x7f96808976a0>
# 		.Softmax -> <syft.ast.klass.Class object at 0x7f9680897b20>
# 		.Softmax2d -> <syft.ast.klass.Class object at 0x7f9680897fa0>
# 		.Softmin -> <syft.ast.klass.Class object at 0x7f968089b460>
# 		.Softplus -> <syft.ast.klass.Class object at 0x7f968089b8e0>
# 		.Softshrink -> <syft.ast.klass.Class object at 0x7f968089bd60>
# 		.Softsign -> <syft.ast.klass.Class object at 0x7f96808a1220>
# 		.SyncBatchNorm -> <syft.ast.klass.Class object at 0x7f96808a16a0>
# 		.Tanh -> <syft.ast.klass.Class object at 0x7f96808a1c40>
# 		.Tanhshrink -> <syft.ast.klass.Class object at 0x7f96808a30a0>
# 		.Threshold -> <syft.ast.klass.Class object at 0x7f96808a3520>
# 		.Transformer -> <syft.ast.klass.Class object at 0x7f96808a39a0>
# 		.TransformerDecoder -> <syft.ast.klass.Class object at 0x7f96808a3e20>
# 		.TransformerDecoderLayer -> <syft.ast.klass.Class object at 0x7f96808a8580>
# 		.TransformerEncoder -> <syft.ast.klass.Class object at 0x7f96808a8be0>
# 		.TransformerEncoderLayer -> <syft.ast.klass.Class object at 0x7f96808aa340>
# 		.Unfold -> <syft.ast.klass.Class object at 0x7f96808aa9a0>
# 		.Upsample -> <syft.ast.klass.Class object at 0x7f96808aadc0>
# 		.UpsamplingBilinear2d -> <syft.ast.klass.Class object at 0x7f96808ae280>
# 		.UpsamplingNearest2d -> <syft.ast.klass.Class object at 0x7f96808ae940>
# 		.ZeroPad2d -> <syft.ast.klass.Class object at 0x7f96808b10a0>
#
# 	.return_types -> Module:
# 		.cummax -> <syft.ast.klass.Class object at 0x7f968099cb80>
# 		.cummin -> <syft.ast.klass.Class object at 0x7f968099cbe0>
# 		.eig -> <syft.ast.klass.Class object at 0x7f968099cc40>
# 		.kthvalue -> <syft.ast.klass.Class object at 0x7f968099cca0>
# 		.lstsq -> <syft.ast.klass.Class object at 0x7f968099cd00>
# 		.slogdet -> <syft.ast.klass.Class object at 0x7f968099cd60>
# 		.qr -> <syft.ast.klass.Class object at 0x7f968099cdc0>
# 		.mode -> <syft.ast.klass.Class object at 0x7f968099ce20>
# 		.solve -> <syft.ast.klass.Class object at 0x7f968099ce80>
# 		.sort -> <syft.ast.klass.Class object at 0x7f968099cee0>
# 		.symeig -> <syft.ast.klass.Class object at 0x7f968099cf40>
# 		.topk -> <syft.ast.klass.Class object at 0x7f968099cfa0>
# 		.triangular_solve -> <syft.ast.klass.Class object at 0x7f96809a10a0>
# 		.svd -> <syft.ast.klass.Class object at 0x7f96809a1100>
# 		.geqrf -> <syft.ast.klass.Class object at 0x7f96809a1160>
# 		.median -> <syft.ast.klass.Class object at 0x7f96809a11c0>
# 		.max -> <syft.ast.klass.Class object at 0x7f96809a1220>
# 		.min -> <syft.ast.klass.Class object at 0x7f96809a1280>
#
# 	.Size -> <syft.ast.klass.Class object at 0x7f9680979460>
# 	.set_grad_enabled -> <syft.ast.klass.Class object at 0x7f9680979760>
# 	.zeros -> <syft.ast.callable.Callable object at 0x7f96809797c0>
# 	.randn -> <syft.ast.callable.Callable object at 0x7f9680979820>
# 	.ones_like -> <syft.ast.callable.Callable object at 0x7f9680979880>
# 	.arange -> <syft.ast.callable.Callable object at 0x7f96809799a0>
# 	.abs_ -> <syft.ast.callable.Callable object at 0x7f9680979a00>
# 	.abs -> <syft.ast.callable.Callable object at 0x7f9680979a60>
# 	.acos_ -> <syft.ast.callable.Callable object at 0x7f9680979ac0>
# 	.acos -> <syft.ast.callable.Callable object at 0x7f9680979b20>
# 	.add -> <syft.ast.callable.Callable object at 0x7f9680979b80>
# 	.addbmm -> <syft.ast.callable.Callable object at 0x7f9680979be0>
# 	.addcdiv -> <syft.ast.callable.Callable object at 0x7f9680979c40>
# 	.addcmul -> <syft.ast.callable.Callable object at 0x7f9680979ca0>
# 	.addmm -> <syft.ast.callable.Callable object at 0x7f9680979d00>
# 	.addmv_ -> <syft.ast.callable.Callable object at 0x7f9680979d60>
# 	.addmv -> <syft.ast.callable.Callable object at 0x7f9680979dc0>
# 	.addr -> <syft.ast.callable.Callable object at 0x7f9680979e20>
# 	.all -> <syft.ast.callable.Callable object at 0x7f9680979e80>
# 	.allclose -> <syft.ast.callable.Callable object at 0x7f9680979ee0>
# 	.angle -> <syft.ast.callable.Callable object at 0x7f9680979f40>
# 	.any -> <syft.ast.callable.Callable object at 0x7f9680979fa0>
# 	.argmax -> <syft.ast.callable.Callable object at 0x7f968097e040>
# 	.argmin -> <syft.ast.callable.Callable object at 0x7f968097e0a0>
# 	.argsort -> <syft.ast.callable.Callable object at 0x7f968097e100>
# 	.as_strided_ -> <syft.ast.callable.Callable object at 0x7f968097e160>
# 	.as_strided -> <syft.ast.callable.Callable object at 0x7f968097e1c0>
# 	.asin_ -> <syft.ast.callable.Callable object at 0x7f968097e220>
# 	.asin -> <syft.ast.callable.Callable object at 0x7f968097e280>
# 	.atan_ -> <syft.ast.callable.Callable object at 0x7f968097e2e0>
# 	.atan -> <syft.ast.callable.Callable object at 0x7f968097e340>
# 	.atan2 -> <syft.ast.callable.Callable object at 0x7f968097e3a0>
# 	.baddbmm -> <syft.ast.callable.Callable object at 0x7f968097e400>
# 	.bernoulli -> <syft.ast.callable.Callable object at 0x7f968097e460>
# 	.bitwise_and -> <syft.ast.callable.Callable object at 0x7f968097e4c0>
# 	.bitwise_not -> <syft.ast.callable.Callable object at 0x7f968097e520>
# 	.bitwise_or -> <syft.ast.callable.Callable object at 0x7f968097e580>
# 	.bitwise_xor -> <syft.ast.callable.Callable object at 0x7f968097e5e0>
# 	.bmm -> <syft.ast.callable.Callable object at 0x7f968097e640>
# 	.cat -> <syft.ast.callable.Callable object at 0x7f968097e6a0>
# 	.ceil_ -> <syft.ast.callable.Callable object at 0x7f968097e700>
# 	.ceil -> <syft.ast.callable.Callable object at 0x7f968097e760>
# 	.cholesky_inverse -> <syft.ast.callable.Callable object at 0x7f968097e7c0>
# 	.cholesky_solve -> <syft.ast.callable.Callable object at 0x7f968097e820>
# 	.cholesky -> <syft.ast.callable.Callable object at 0x7f968097e880>
# 	.chunk -> <syft.ast.callable.Callable object at 0x7f968097e8e0>
# 	.clamp_ -> <syft.ast.callable.Callable object at 0x7f968097e940>
# 	.clamp_max_ -> <syft.ast.callable.Callable object at 0x7f968097e9a0>
# 	.clamp_max -> <syft.ast.callable.Callable object at 0x7f968097ea00>
# 	.clamp_min_ -> <syft.ast.callable.Callable object at 0x7f968097ea60>
# 	.clamp_min -> <syft.ast.callable.Callable object at 0x7f968097eac0>
# 	.clamp -> <syft.ast.callable.Callable object at 0x7f968097eb20>
# 	.clone -> <syft.ast.callable.Callable object at 0x7f968097eb80>
# 	.conj -> <syft.ast.callable.Callable object at 0x7f968097ebe0>
# 	.cos_ -> <syft.ast.callable.Callable object at 0x7f968097ec40>
# 	.cos -> <syft.ast.callable.Callable object at 0x7f968097eca0>
# 	.cosh_ -> <syft.ast.callable.Callable object at 0x7f968097ed00>
# 	.cosh -> <syft.ast.callable.Callable object at 0x7f968097ed60>
# 	.cross -> <syft.ast.callable.Callable object at 0x7f968097edc0>
# 	.cummax -> <syft.ast.callable.Callable object at 0x7f968097ee20>
# 	.cummin -> <syft.ast.callable.Callable object at 0x7f968097ee80>
# 	.cumprod -> <syft.ast.callable.Callable object at 0x7f968097eee0>
# 	.cumsum -> <syft.ast.callable.Callable object at 0x7f968097ef40>
# 	.dequantize -> <syft.ast.callable.Callable object at 0x7f968097efa0>
# 	.det -> <syft.ast.callable.Callable object at 0x7f9680903040>
# 	.detach -> <syft.ast.callable.Callable object at 0x7f96809030a0>
# 	.diag_embed -> <syft.ast.callable.Callable object at 0x7f9680903100>
# 	.diag -> <syft.ast.callable.Callable object at 0x7f9680903160>
# 	.diagflat -> <syft.ast.callable.Callable object at 0x7f96809031c0>
# 	.diagonal -> <syft.ast.callable.Callable object at 0x7f9680903220>
# 	.digamma -> <syft.ast.callable.Callable object at 0x7f9680903280>
# 	.dist -> <syft.ast.callable.Callable object at 0x7f96809032e0>
# 	.div -> <syft.ast.callable.Callable object at 0x7f9680903340>
# 	.dot -> <syft.ast.callable.Callable object at 0x7f96809033a0>
# 	.eig -> <syft.ast.callable.Callable object at 0x7f9680903400>
# 	.eq -> <syft.ast.callable.Callable object at 0x7f9680903460>
# 	.equal -> <syft.ast.callable.Callable object at 0x7f96809034c0>
# 	.erf_ -> <syft.ast.callable.Callable object at 0x7f9680903520>
# 	.erf -> <syft.ast.callable.Callable object at 0x7f9680903580>
# 	.erfc_ -> <syft.ast.callable.Callable object at 0x7f96809035e0>
# 	.erfc -> <syft.ast.callable.Callable object at 0x7f9680903640>
# 	.erfinv -> <syft.ast.callable.Callable object at 0x7f96809036a0>
# 	.exp_ -> <syft.ast.callable.Callable object at 0x7f9680903700>
# 	.exp -> <syft.ast.callable.Callable object at 0x7f9680903760>
# 	.expm1_ -> <syft.ast.callable.Callable object at 0x7f96809037c0>
# 	.expm1 -> <syft.ast.callable.Callable object at 0x7f9680903820>
# 	.fft -> Module:
#
# 	.fill_ -> <syft.ast.callable.Callable object at 0x7f96809038e0>
# 	.flatten -> <syft.ast.callable.Callable object at 0x7f9680903940>
# 	.flip -> <syft.ast.callable.Callable object at 0x7f96809039a0>
# 	.floor_ -> <syft.ast.callable.Callable object at 0x7f9680903a00>
# 	.floor_divide -> <syft.ast.callable.Callable object at 0x7f9680903a60>
# 	.floor -> <syft.ast.callable.Callable object at 0x7f9680903ac0>
# 	.fmod -> <syft.ast.callable.Callable object at 0x7f9680903b20>
# 	.frac_ -> <syft.ast.callable.Callable object at 0x7f9680903b80>
# 	.frac -> <syft.ast.callable.Callable object at 0x7f9680903be0>
# 	.from_numpy -> <syft.ast.callable.Callable object at 0x7f9680903c40>
# 	.gather -> <syft.ast.callable.Callable object at 0x7f9680903ca0>
# 	.ge -> <syft.ast.callable.Callable object at 0x7f9680903d00>
# 	.geqrf -> <syft.ast.callable.Callable object at 0x7f9680903d60>
# 	.ger -> <syft.ast.callable.Callable object at 0x7f9680903dc0>
# 	.get_device -> <syft.ast.callable.Callable object at 0x7f9680903e20>
# 	.gt -> <syft.ast.callable.Callable object at 0x7f9680903e80>
# 	.hardshrink -> <syft.ast.callable.Callable object at 0x7f9680903ee0>
# 	.histc -> <syft.ast.callable.Callable object at 0x7f9680903f40>
# 	.index_add -> <syft.ast.callable.Callable object at 0x7f9680903fa0>
# 	.index_copy -> <syft.ast.callable.Callable object at 0x7f9680906040>
# 	.index_fill -> <syft.ast.callable.Callable object at 0x7f96809060a0>
# 	.index_put_ -> <syft.ast.callable.Callable object at 0x7f9680906100>
# 	.index_put -> <syft.ast.callable.Callable object at 0x7f9680906160>
# 	.index_select -> <syft.ast.callable.Callable object at 0x7f96809061c0>
# 	.int_repr -> <syft.ast.callable.Callable object at 0x7f9680906220>
# 	.inverse -> <syft.ast.callable.Callable object at 0x7f9680906280>
# 	.is_complex -> <syft.ast.callable.Callable object at 0x7f96809062e0>
# 	.is_distributed -> <syft.ast.callable.Callable object at 0x7f9680906340>
# 	.is_floating_point -> <syft.ast.callable.Callable object at 0x7f96809063a0>
# 	.is_nonzero -> <syft.ast.callable.Callable object at 0x7f9680906400>
# 	.is_same_size -> <syft.ast.callable.Callable object at 0x7f9680906460>
# 	.is_signed -> <syft.ast.callable.Callable object at 0x7f96809064c0>
# 	.isclose -> <syft.ast.callable.Callable object at 0x7f9680906520>
# 	.kthvalue -> <syft.ast.callable.Callable object at 0x7f9680906580>
# 	.le -> <syft.ast.callable.Callable object at 0x7f96809065e0>
# 	.lerp -> <syft.ast.callable.Callable object at 0x7f9680906640>
# 	.lgamma -> <syft.ast.callable.Callable object at 0x7f96809066a0>
# 	.log_ -> <syft.ast.callable.Callable object at 0x7f9680906700>
# 	.log_softmax -> <syft.ast.callable.Callable object at 0x7f9680906760>
# 	.log -> <syft.ast.callable.Callable object at 0x7f96809067c0>
# 	.log10_ -> <syft.ast.callable.Callable object at 0x7f9680906820>
# 	.log10 -> <syft.ast.callable.Callable object at 0x7f9680906880>
# 	.log1p_ -> <syft.ast.callable.Callable object at 0x7f96809068e0>
# 	.log1p -> <syft.ast.callable.Callable object at 0x7f9680906940>
# 	.log2_ -> <syft.ast.callable.Callable object at 0x7f96809069a0>
# 	.log2 -> <syft.ast.callable.Callable object at 0x7f9680906a00>
# 	.logdet -> <syft.ast.callable.Callable object at 0x7f9680906a60>
# 	.logical_and -> <syft.ast.callable.Callable object at 0x7f9680906ac0>
# 	.logical_not -> <syft.ast.callable.Callable object at 0x7f9680906b20>
# 	.logical_or -> <syft.ast.callable.Callable object at 0x7f9680906b80>
# 	.logical_xor -> <syft.ast.callable.Callable object at 0x7f9680906be0>
# 	.logsumexp -> <syft.ast.callable.Callable object at 0x7f9680906c40>
# 	.lstsq -> <syft.ast.callable.Callable object at 0x7f9680906ca0>
# 	.lt -> <syft.ast.callable.Callable object at 0x7f9680906d00>
# 	.lu_solve -> <syft.ast.callable.Callable object at 0x7f9680906d60>
# 	.lu -> <syft.ast.callable.Callable object at 0x7f9680906dc0>
# 	.masked_fill -> <syft.ast.callable.Callable object at 0x7f9680906e20>
# 	.masked_scatter -> <syft.ast.callable.Callable object at 0x7f9680906e80>
# 	.masked_select -> <syft.ast.callable.Callable object at 0x7f9680906ee0>
# 	.matmul -> <syft.ast.callable.Callable object at 0x7f9680906f40>
# 	.matrix_power -> <syft.ast.callable.Callable object at 0x7f9680906fa0>
# 	.mean -> <syft.ast.callable.Callable object at 0x7f968090b040>
# 	.mm -> <syft.ast.callable.Callable object at 0x7f968090b0a0>
# 	.mode -> <syft.ast.callable.Callable object at 0x7f968090b100>
# 	.mul -> <syft.ast.callable.Callable object at 0x7f968090b160>
# 	.multinomial -> <syft.ast.callable.Callable object at 0x7f968090b1c0>
# 	.mv -> <syft.ast.callable.Callable object at 0x7f968090b220>
# 	.mvlgamma -> <syft.ast.callable.Callable object at 0x7f968090b280>
# 	.narrow -> <syft.ast.callable.Callable object at 0x7f968090b2e0>
# 	.ne -> <syft.ast.callable.Callable object at 0x7f968090b340>
# 	.neg_ -> <syft.ast.callable.Callable object at 0x7f968090b3a0>
# 	.neg -> <syft.ast.callable.Callable object at 0x7f968090b400>
# 	.nonzero -> <syft.ast.callable.Callable object at 0x7f968090b460>
# 	.norm -> <syft.ast.callable.Callable object at 0x7f968090b4c0>
# 	.orgqr -> <syft.ast.callable.Callable object at 0x7f968090b520>
# 	.ormqr -> <syft.ast.callable.Callable object at 0x7f968090b580>
# 	.pinverse -> <syft.ast.callable.Callable object at 0x7f968090b5e0>
# 	.polygamma -> <syft.ast.callable.Callable object at 0x7f968090b640>
# 	.pow -> <syft.ast.callable.Callable object at 0x7f968090b6a0>
# 	.prelu -> <syft.ast.callable.Callable object at 0x7f968090b700>
# 	.q_per_channel_axis -> <syft.ast.callable.Callable object at 0x7f968090b760>
# 	.q_per_channel_scales -> <syft.ast.callable.Callable object at 0x7f968090b7c0>
# 	.q_per_channel_zero_points -> <syft.ast.callable.Callable object at 0x7f968090b820>
# 	.q_scale -> <syft.ast.callable.Callable object at 0x7f968090b880>
# 	.q_zero_point -> <syft.ast.callable.Callable object at 0x7f968090b8e0>
# 	.qr -> <syft.ast.callable.Callable object at 0x7f968090b940>
# 	.reciprocal_ -> <syft.ast.callable.Callable object at 0x7f968090b9a0>
# 	.reciprocal -> <syft.ast.callable.Callable object at 0x7f968090ba00>
# 	.relu_ -> <syft.ast.callable.Callable object at 0x7f968090ba60>
# 	.relu -> <syft.ast.callable.Callable object at 0x7f968090bac0>
# 	.remainder -> <syft.ast.callable.Callable object at 0x7f968090bb20>
# 	.renorm -> <syft.ast.callable.Callable object at 0x7f968090bb80>
# 	.repeat_interleave -> <syft.ast.callable.Callable object at 0x7f968090bbe0>
# 	.reshape -> <syft.ast.callable.Callable object at 0x7f968090bc40>
# 	.resize_as_ -> <syft.ast.callable.Callable object at 0x7f968090bca0>
# 	.roll -> <syft.ast.callable.Callable object at 0x7f968090bd00>
# 	.rot90 -> <syft.ast.callable.Callable object at 0x7f968090bd60>
# 	.round_ -> <syft.ast.callable.Callable object at 0x7f968090bdc0>
# 	.round -> <syft.ast.callable.Callable object at 0x7f968090be20>
# 	.rsqrt_ -> <syft.ast.callable.Callable object at 0x7f968090be80>
# 	.rsqrt -> <syft.ast.callable.Callable object at 0x7f968090bee0>
# 	.scatter_add -> <syft.ast.callable.Callable object at 0x7f968090bf40>
# 	.scatter -> <syft.ast.callable.Callable object at 0x7f968090bfa0>
# 	.select -> <syft.ast.callable.Callable object at 0x7f968090f040>
# 	.sigmoid_ -> <syft.ast.callable.Callable object at 0x7f968090f0a0>
# 	.sigmoid -> <syft.ast.callable.Callable object at 0x7f968090f100>
# 	.sign -> <syft.ast.callable.Callable object at 0x7f968090f160>
# 	.sin_ -> <syft.ast.callable.Callable object at 0x7f968090f1c0>
# 	.sin -> <syft.ast.callable.Callable object at 0x7f968090f220>
# 	.sinh_ -> <syft.ast.callable.Callable object at 0x7f968090f280>
# 	.sinh -> <syft.ast.callable.Callable object at 0x7f968090f2e0>
# 	.slogdet -> <syft.ast.callable.Callable object at 0x7f968090f340>
# 	.softmax -> <syft.ast.callable.Callable object at 0x7f968090f3a0>
# 	.solve -> <syft.ast.callable.Callable object at 0x7f968090f400>
# 	.sort -> <syft.ast.callable.Callable object at 0x7f968090f460>
# 	.split_with_sizes -> <syft.ast.callable.Callable object at 0x7f968090f4c0>
# 	.split -> <syft.ast.callable.Callable object at 0x7f968090f520>
# 	.sqrt_ -> <syft.ast.callable.Callable object at 0x7f968090f580>
# 	.sqrt -> <syft.ast.callable.Callable object at 0x7f968090f5e0>
# 	.square_ -> <syft.ast.callable.Callable object at 0x7f968090f640>
# 	.square -> <syft.ast.callable.Callable object at 0x7f968090f6a0>
# 	.squeeze -> <syft.ast.callable.Callable object at 0x7f968090f700>
# 	.stack -> <syft.ast.callable.Callable object at 0x7f968090f760>
# 	.std -> <syft.ast.callable.Callable object at 0x7f968090f7c0>
# 	.stft -> <syft.ast.callable.Callable object at 0x7f968090f820>
# 	.sub -> <syft.ast.callable.Callable object at 0x7f968090f880>
# 	.sum -> <syft.ast.callable.Callable object at 0x7f968090f8e0>
# 	.svd -> <syft.ast.callable.Callable object at 0x7f968090f940>
# 	.symeig -> <syft.ast.callable.Callable object at 0x7f968090f9a0>
# 	.t -> <syft.ast.callable.Callable object at 0x7f968090fa00>
# 	.take -> <syft.ast.callable.Callable object at 0x7f968090fa60>
# 	.tan_ -> <syft.ast.callable.Callable object at 0x7f968090fac0>
# 	.tan -> <syft.ast.callable.Callable object at 0x7f968090fb20>
# 	.tanh_ -> <syft.ast.callable.Callable object at 0x7f968090fb80>
# 	.tanh -> <syft.ast.callable.Callable object at 0x7f968090fbe0>
# 	.topk -> <syft.ast.callable.Callable object at 0x7f968090fc40>
# 	.trace -> <syft.ast.callable.Callable object at 0x7f968090fca0>
# 	.transpose -> <syft.ast.callable.Callable object at 0x7f968090fd00>
# 	.triangular_solve -> <syft.ast.callable.Callable object at 0x7f968090fd60>
# 	.tril -> <syft.ast.callable.Callable object at 0x7f968090fdc0>
# 	.triu -> <syft.ast.callable.Callable object at 0x7f968090fe20>
# 	.true_divide -> <syft.ast.callable.Callable object at 0x7f968090fe80>
# 	.trunc_ -> <syft.ast.callable.Callable object at 0x7f968090fee0>
# 	.trunc -> <syft.ast.callable.Callable object at 0x7f968090ff40>
# 	.unique_consecutive -> <syft.ast.callable.Callable object at 0x7f968090ffa0>
# 	.unique -> <syft.ast.callable.Callable object at 0x7f9680914040>
# 	.unsqueeze -> <syft.ast.callable.Callable object at 0x7f96809140a0>
# 	.var -> <syft.ast.callable.Callable object at 0x7f9680914100>
# 	.unsafe_chunk -> <syft.ast.callable.Callable object at 0x7f9680914160>
# 	.absolute -> <syft.ast.callable.Callable object at 0x7f96809141c0>
# 	.acosh_ -> <syft.ast.callable.Callable object at 0x7f9680914220>
# 	.acosh -> <syft.ast.callable.Callable object at 0x7f9680914280>
# 	.asinh_ -> <syft.ast.callable.Callable object at 0x7f96809142e0>
# 	.asinh -> <syft.ast.callable.Callable object at 0x7f9680914340>
# 	.atanh_ -> <syft.ast.callable.Callable object at 0x7f96809143a0>
# 	.atanh -> <syft.ast.callable.Callable object at 0x7f9680914400>
# 	.deg2rad_ -> <syft.ast.callable.Callable object at 0x7f9680914460>
# 	.deg2rad -> <syft.ast.callable.Callable object at 0x7f96809144c0>
# 	.fliplr -> <syft.ast.callable.Callable object at 0x7f9680914520>
# 	.flipud -> <syft.ast.callable.Callable object at 0x7f9680914580>
# 	.isfinite -> <syft.ast.callable.Callable object at 0x7f96809145e0>
# 	.isinf -> <syft.ast.callable.Callable object at 0x7f9680914640>
# 	.isnan -> <syft.ast.callable.Callable object at 0x7f96809146a0>
# 	.logaddexp -> <syft.ast.callable.Callable object at 0x7f9680914700>
# 	.logaddexp2 -> <syft.ast.callable.Callable object at 0x7f9680914760>
# 	.logcumsumexp -> <syft.ast.callable.Callable object at 0x7f96809147c0>
# 	.rad2deg_ -> <syft.ast.callable.Callable object at 0x7f9680914820>
# 	.rad2deg -> <syft.ast.callable.Callable object at 0x7f9680914880>
# 	.istft -> <syft.ast.callable.Callable object at 0x7f96809148e0>
# 	.amax -> <syft.ast.callable.Callable object at 0x7f9680914940>
# 	.amin -> <syft.ast.callable.Callable object at 0x7f96809149a0>
# 	.arccos -> <syft.ast.callable.Callable object at 0x7f9680914a00>
# 	.arccos_ -> <syft.ast.callable.Callable object at 0x7f9680914a60>
# 	.arccosh -> <syft.ast.callable.Callable object at 0x7f9680914ac0>
# 	.arccosh_ -> <syft.ast.callable.Callable object at 0x7f9680914b20>
# 	.arcsin -> <syft.ast.callable.Callable object at 0x7f9680914b80>
# 	.arcsin_ -> <syft.ast.callable.Callable object at 0x7f9680914be0>
# 	.arcsinh -> <syft.ast.callable.Callable object at 0x7f9680914c40>
# 	.arcsinh_ -> <syft.ast.callable.Callable object at 0x7f9680914ca0>
# 	.arctan -> <syft.ast.callable.Callable object at 0x7f9680914d00>
# 	.arctan_ -> <syft.ast.callable.Callable object at 0x7f9680914d60>
# 	.arctanh -> <syft.ast.callable.Callable object at 0x7f9680914dc0>
# 	.arctanh_ -> <syft.ast.callable.Callable object at 0x7f9680914e20>
# 	.clip -> <syft.ast.callable.Callable object at 0x7f9680914e80>
# 	.clip_ -> <syft.ast.callable.Callable object at 0x7f9680914ee0>
# 	.count_nonzero -> <syft.ast.callable.Callable object at 0x7f9680914f40>
# 	.divide -> <syft.ast.callable.Callable object at 0x7f9680914fa0>
# 	.exp2 -> <syft.ast.callable.Callable object at 0x7f96809180a0>
# 	.exp2_ -> <syft.ast.callable.Callable object at 0x7f9680918100>
# 	.fix -> <syft.ast.callable.Callable object at 0x7f9680918160>
# 	.fix_ -> <syft.ast.callable.Callable object at 0x7f96809181c0>
# 	.gcd -> <syft.ast.callable.Callable object at 0x7f9680918220>
# 	.gcd_ -> <syft.ast.callable.Callable object at 0x7f9680918280>
# 	.greater -> <syft.ast.callable.Callable object at 0x7f96809182e0>
# 	.greater_equal -> <syft.ast.callable.Callable object at 0x7f9680918340>
# 	.heaviside -> <syft.ast.callable.Callable object at 0x7f96809183a0>
# 	.hypot -> <syft.ast.callable.Callable object at 0x7f9680918400>
# 	.i0 -> <syft.ast.callable.Callable object at 0x7f9680918460>
# 	.i0_ -> <syft.ast.callable.Callable object at 0x7f96809184c0>
# 	.isneginf -> <syft.ast.callable.Callable object at 0x7f9680918520>
# 	.isposinf -> <syft.ast.callable.Callable object at 0x7f9680918580>
# 	.isreal -> <syft.ast.callable.Callable object at 0x7f96809185e0>
# 	.lcm -> <syft.ast.callable.Callable object at 0x7f9680918640>
# 	.lcm_ -> <syft.ast.callable.Callable object at 0x7f96809186a0>
# 	.less -> <syft.ast.callable.Callable object at 0x7f9680918700>
# 	.less_equal -> <syft.ast.callable.Callable object at 0x7f9680918760>
# 	.logit -> <syft.ast.callable.Callable object at 0x7f96809187c0>
# 	.logit_ -> <syft.ast.callable.Callable object at 0x7f9680918820>
# 	.maximum -> <syft.ast.callable.Callable object at 0x7f9680918880>
# 	.minimum -> <syft.ast.callable.Callable object at 0x7f96809188e0>
# 	.matrix_exp -> <syft.ast.callable.Callable object at 0x7f9680918940>
# 	.multiply -> <syft.ast.callable.Callable object at 0x7f96809189a0>
# 	.nanquantile -> <syft.ast.callable.Callable object at 0x7f9680918a00>
# 	.nansum -> <syft.ast.callable.Callable object at 0x7f9680918a60>
# 	.negative -> <syft.ast.callable.Callable object at 0x7f9680918ac0>
# 	.negative_ -> <syft.ast.callable.Callable object at 0x7f9680918b20>
# 	.nextafter -> <syft.ast.callable.Callable object at 0x7f9680918b80>
# 	.outer -> <syft.ast.callable.Callable object at 0x7f9680918be0>
# 	.quantile -> <syft.ast.callable.Callable object at 0x7f9680918c40>
# 	.sgn -> <syft.ast.callable.Callable object at 0x7f9680918ca0>
# 	.signbit -> <syft.ast.callable.Callable object at 0x7f9680918d00>
# 	.subtract -> <syft.ast.callable.Callable object at 0x7f9680918d60>
# 	.unsafe_split -> <syft.ast.callable.Callable object at 0x7f9680918dc0>
# 	.vdot -> <syft.ast.callable.Callable object at 0x7f9680918e20>
# 	.movedim -> <syft.ast.callable.Callable object at 0x7f9680918e80>
# 	.unsafe_split_with_sizes -> <syft.ast.callable.Callable object at 0x7f9680918ee0>
# 	.cuda -> Module:
# 		.is_available -> <syft.ast.callable.Callable object at 0x7f9680918fa0>
#
# 	.device -> <syft.ast.klass.Class object at 0x7f968091d040>
# 	.random -> Module:
# 		.initial_seed -> <syft.ast.callable.Callable object at 0x7f968091d1c0>
#
# 	.zeros_like -> <syft.ast.callable.Callable object at 0x7f968091d220>
# 	.manual_seed -> <syft.ast.callable.Callable object at 0x7f968091d280>
# 	.Generator -> <syft.ast.klass.Class object at 0x7f968091d2e0>
# 	.utils -> Module:
# 		.data -> Module:
# 			.DataLoader -> <syft.ast.klass.Class object at 0x7f96809215e0>
# 			.dataloader -> Module:
# 				._SingleProcessDataLoaderIter -> <syft.ast.klass.Class object at 0x7f9680921820>
#
#
#
# 	.optim -> Module:
# 		.ASGD -> <syft.ast.klass.Class object at 0x7f9680921be0>
# 		.Adadelta -> <syft.ast.klass.Class object at 0x7f9680921d60>
# 		.Adagrad -> <syft.ast.klass.Class object at 0x7f9680921ee0>
# 		.Adam -> <syft.ast.klass.Class object at 0x7f96809260a0>
# 		.AdamW -> <syft.ast.klass.Class object at 0x7f9680926220>
# 		.Adamax -> <syft.ast.klass.Class object at 0x7f96809263a0>
# 		.LBFGS -> <syft.ast.klass.Class object at 0x7f9680926520>
# 		.Optimizer -> <syft.ast.klass.Class object at 0x7f96809266a0>
# 		.RMSprop -> <syft.ast.klass.Class object at 0x7f9680926880>
# 		.Rprop -> <syft.ast.klass.Class object at 0x7f9680926a00>
# 		.SGD -> <syft.ast.klass.Class object at 0x7f9680926b80>
# 		.SparseAdam -> <syft.ast.klass.Class object at 0x7f9680926d00>
# 		.lr_scheduler -> Module:
# 			.StepLR -> <syft.ast.klass.Class object at 0x7f9680926fa0>
#
#
# 	.no_grad -> <syft.ast.klass.Class object at 0x7f968092b1c0>
# 	.autograd -> Module:
# 		.grad_mode -> Module:
# 			.no_grad -> <syft.ast.klass.Class object at 0x7f968092b340>
#
#
# 	.distributions -> Module:
# 		.Categorical -> <syft.ast.klass.Class object at 0x7f96808b1580>
#
# 	.kron -> <syft.ast.callable.Callable object at 0x7f96808b1b20>
# 	.msort -> <syft.ast.callable.Callable object at 0x7f96808b1c40>
# 	.row_stack -> <syft.ast.callable.Callable object at 0x7f96808b1ca0>
# 	.moveaxis -> <syft.ast.callable.Callable object at 0x7f96808b1fa0>
# 	.tensor_split -> <syft.ast.callable.Callable object at 0x7f96808b5100>
# 	.tile -> <syft.ast.callable.Callable object at 0x7f96808b5220>
# 	.fmin -> <syft.ast.callable.Callable object at 0x7f96808b5400>
# 	.ldexp -> <syft.ast.callable.Callable object at 0x7f96808b5460>
# 	.igamma -> <syft.ast.callable.Callable object at 0x7f96808b5580>
# 	.float_power -> <syft.ast.callable.Callable object at 0x7f96808b5a60>
# 	.xlogy -> <syft.ast.callable.Callable object at 0x7f96808b5b80>
# 	.copysign -> <syft.ast.callable.Callable object at 0x7f96808b5be0>
# 	.nanmedian -> <syft.ast.callable.Callable object at 0x7f96808b5c40>
# 	.igammac -> <syft.ast.callable.Callable object at 0x7f96808b5ca0>
# 	.diff -> <syft.ast.callable.Callable object at 0x7f96808b5dc0>
# 	.sinc -> <syft.ast.callable.Callable object at 0x7f96808b5ee0>
# 	.column_stack -> <syft.ast.callable.Callable object at 0x7f96808ba100>
# 	.pixel_unshuffle -> <syft.ast.callable.Callable object at 0x7f96808ba220>
# 	.swapaxes -> <syft.ast.callable.Callable object at 0x7f96808ba4c0>
# 	.nan_to_num -> <syft.ast.callable.Callable object at 0x7f96808ba520>
# 	.inner -> <syft.ast.callable.Callable object at 0x7f96808ba580>
# 	.fmax -> <syft.ast.callable.Callable object at 0x7f96808ba5e0>
# 	.ravel -> <syft.ast.callable.Callable object at 0x7f96808ba940>
# 	.broadcast_to -> <syft.ast.callable.Callable object at 0x7f96808ba9a0>
# 	.swapdims -> <syft.ast.callable.Callable object at 0x7f96808bab80>

# %%
def BMI_calculator(w_ptr, h_ptr):
    
    bmi_ptr = 0

    ##TODO "Write your code here for calculating bmi_ptr"
    bmi_ptr=(w_ptr.float()/h_ptr.float().pow(2))*10000
 

    ###

    return bmi_ptr

# %%
def weight_status(w_ptr, h_ptr):

    status = None

    bmi_ptr = BMI_calculator(w_ptr, h_ptr)

    ##TODO

    value=bmi_ptr.get(request_block=True,reason="see values")
    if (value >=19. and  value <25. ):
        status="Normal"
    elif (value >=25. and  value < 30. ):
        status="Overweight"
    elif (value >=30. and  value <= 39. ):
        status="Obese"
    else:
        status="Out of range"
    
        

    ###
    
    return status

# %%
for i in range(0, 6):
    bmi_ptr = BMI_calculator(weights_ptr[i], heights_ptr[i])

# %%
statuses = []
for i in range(0, 6):
    status = weight_status(weights_ptr[i], heights_ptr[i])
    print("Weight of Person", i + 1, "is", status)
    statuses.append(status)

assert statuses == ["Normal", "Overweight", "Obese", "Normal", "Overweight", "Normal"]
# Out:
# Weight of Person 1 is Normal
# Weight of Person 2 is Overweight
# Weight of Person 3 is Obese
# Weight of Person 4 is Normal
# Weight of Person 5 is Overweight
# Weight of Person 6 is Normal
